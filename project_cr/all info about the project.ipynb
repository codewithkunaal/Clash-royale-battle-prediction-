# %% [markdown]
# ## what is clash royale ?

# %% [markdown]
#  Clash Royale is a free-to-play real-time strategy video game developed and published by Supercell.
#  The game combines elements from collectible card games, tower defense, and multiplayer online battle arena.
#  The game was released globally on March 2, 2016.
#
# Clash Royale is a tower rush video game which pits players in games featuring two or four players (1v1 or 2v2) in which the objective is to destroy the most opposing towers, with the destruction of the "King's Tower" being an instantaneous win.
# After three minutes, if both of the players/teams have an equal number of crowns or none at all the match continues into a 2-minute overtime period and the player who destroys an opposing tower wins instantaneously.
# If no towers are destroyed during overtime, there is a tiebreaker where all towers rapidly lose health, and the tower with the least health is destroyed.
# If the two towers with the lowest health have the same health, there is a draw.
# After an update in late 2018, leaving a 2v2 match multiple times prevents the player from playing 2v2 with random players for some time.
# a player wins a battle by destroying more towers than the opponent (each destroyed tower being represented as a 'crown'), or by destroying the opponent's King's Tower, resulting in an automatic "three-crown" victory, commonly described as being "three-crowned". (unless the King's Tower was destroyed at the same time by both players, resulting in a draw, however this is nearly impossible).

# %%
from IPython.display import Image
Image("A:\machine learning\project\project_cr/Clash_Royale.jpg", width=400, height=400)

# %% [markdown]
# ## problem statement why i did this project?

# %% [markdown]
# based on cards we're playing can we predict the outcome of battle?
# who's gonna win/who's more likely to win?
#
# ## conclusion - what will we get out of this ?
#
#
# can this be really helpful in finding synergy between certain cards?
# helpful in finding card combinations to win more matches?
# training an ai to win against players possible?
# can ai learn the pattern to beat skilled players?
# helpful finding one's weakness against certain cards.... can find which matches were lost most on facing certain cards by specific player

# %% [markdown]
# ## how this is done?

# %% [markdown]
#  steps -
#  1.data collection - royaleapi, statsroyale, deckshop pro and wikipedia
#        - top 5 players matches and all cards info from deckshop pro
#          mapped together
#
#
#
# 2.custom encoding - formula - elixir + power ranking (in terms of most wins and uses 6 being really good 1 being awful)×16.66
#             `formula = elixir + K* 16.66`
#
#
#
#
# 3.target column - player 1 crowns - player 2 crowns  = outcome columns 0 being loss and 1 being win (if +ve then win else lose)
#
#
# 4.alogithms applied - 1.logistic regression
#                        2.random forest
#                        3.svm
#
#
#
# results : accuracy with logistic regression 64%
# accuracy with random forest 84%
# using svm its 64%

# %% [markdown]
# ## drawbacks? why getting the higher accuracy is harder?

# %% [markdown]
# drawbacks -
# 1.card levels - I assumed cards level to be equal(max)
#
# 2.awful player - you cant win matches even if you're using best deck cuz you are generally not good at game
#
# 3.starting hands - starting hands plays huge role in deciding outcome
#
# 4.drop glitch - it's games fault anyway
#
# 5.slow internet speed cause to slow down cards placement
#
# 6.maybe youre tired and not at your best rn
#
# 7.meta changes - supercell keep tweaking the cards stats so same cards are not as prevalent after one month or few weeks
# 8.new cards - every update they add new cards so new cards affect a lot on the battle outcome
